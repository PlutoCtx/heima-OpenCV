# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img = np.zeros((256,256),np.uint8)

plt.imshow(img[:, :, ::-1])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import cv2 as cv
#       3 import matplotlib.pyplot as plt
#       5 img = np.zeros((256,256),np.uint8)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import cv2 as cv
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import cv2 as cv
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import cv2 as cv
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = np.zeros((256,256,3), np.uint8)

# %%
plt.imshow(img[:, :, ::-1])

# %%
img[100,100]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[100,100,0]
# Out:
# 0

# %%
img[100,100] = (0,0,255)

# %%
plt.imshow(img[:, :, ::-1])

# %%
img[100,100]
# Out:
# array([  0,   0, 255], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 img.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.size
# Out:
# 196608

# %%
b,g,r = cv.split(img)
img = cv.merge((b,g,r))

# %%
prince = cv.imread("./image/prince.jpg")

# %%
plt.imshow(prince)

# %%
plt.imshow(prince[:, :, ::-1])

# %%
b,g,r = cv.split(prince)

# %%
plt.imshow(b, cmap = plt.cm.gray)

# %%
img2 = cv.merge([b,g,r])

# %%
plt.imshow(img2[:, :, ::-1])

# %%
gray = cv.cvtColor(prince, cv.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap = plt.cm.gray)

# %%
hsv = cv.cvtColor(prince, cv.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)
