# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
kids = cv.imread("./image/kids.jpg")

# %%
plt.imshow(kids[:, :, ::-1])

# %%
# 绝对尺寸
rows, cols = kids.shape[:2]

# %%
rows
# Out:
# 374

# %%
cols
# Out:
# 500

# %%
res = cv.resize(kids, (2*cols, 2*rows))

# %%
plt.imshow(res[:, :, ::-1])

# %%
res.shape
# Out:
# (748, 1000, 3)

# %%
res1 = cv.resize(kids, None, fx = 0.5, fy =0.5)

# %%
plt.imshow(res1[:, :, ::-1])

# %%
res1.shape
# Out:
# (187, 250, 3)

# %%
# 图像平移
plt.imshow(kids[:, :, ::-1])

# %%
rows
# Out:
# 374

# %%
cols
# Out:
# 500

# %%
M = np.float32([[1,0,100], [0,1,50]])

# %%
res2 = cv.warpAffine(kids, M, (2*cols, 2*rows))

# %% [markdown]
# plt.imshow(res2[:, :, ::-1])

# %% [markdown]
# # 图像旋转

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
M = cv.getRotationMatrix2D((cols/2, rows/2), 45, 1)

# %%
res3 = cv.warpAffine(kids, M, (cols, rows))

# %%
plt.imshow(res3[:, :, ::-1])

# %% [markdown]
# # 仿射变换

# %%
pts1 = np.float32(([50, 50], [200, 50], [50, 200]))
pts2 = np.float32(([100,100], [200, 50], [100, 250]))

# %%
M = cv.getAffineTransform(pts1, pts2)

# %%
M
# Out:
# array([[ 0.66666667,  0.        , 66.66666667],
#        [-0.33333333,  1.        , 66.66666667]])

# %%
res4 = cv.warpAffine(kids, M, (cols, rows))

# %%
plt.imshow(res4[:, :, ::-1])

# %% [markdown]
# # 投射变换

# %%
pst1 = np.float32(([56, 65], [368, 52], [20, 387], [389, 390]))
pst2 = np.float32(([100, 145], [300, 100], [80,290], [310, 300]))

# %%
T = cv.getPerspectiveTransform(pst1, pst2)

# %%
T
# Out:
# array([[ 4.00165499e-01, -5.68324633e-03,  7.41663659e+01],
#        [-1.92295366e-01,  4.45560666e-01,  1.21306120e+02],
#        [-7.19504890e-04,  3.62231058e-05,  1.00000000e+00]])

# %%
res5 = cv.warpPerspective(kids, T, (cols, rows))

# %%
plt.imshow(res5[:, :, ::-1])

# %% [markdown]
# # 图像金字塔

# %%
plt.imshow(kids[:, :, ::-1])

# %%
imgup = cv.pyrUp(kids)

# %%
plt.imshow(imgup[:, :, ::-1])

# %%
imgup2 = cv.pyrUp(imgup)

# %%
plt.imshow(imgup2[:, :, ::-1])

# %%
imgdown = cv.pyrDown(imgup)

# %%
plt.imshow(imgdown[:, :, ::-1])

# %%
imgdown2 = cv.pyrDown(imgdown)

# %%
plt.imshow(imgdown2[:, :, ::-1])
